# %% [markdown]
# ### lab that are we going to learn

# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
from scipy.stats import binom, poisson, norm, t
