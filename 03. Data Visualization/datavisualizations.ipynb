# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns 

df = pd.read_excel('CDAC_DataBook.xlsx',sheet_name='ERPData')

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
# Type Of GRaph : 
# Univerasal : categorical data : bar Chart , Pie chart || continuous : Histogram , Line Chart , BOx Plot 
#  Bivariate : categorical v/s categorical  - grouped pr stached bar
            # categorical vs Contiouns  - Group Box plots 
#           Contiouns vs contineous -  Scater plot 
#  multivariate : more than two variabel

# %%
df.MaterialID.value_counts()
# Out:
# MaterialID
# TMI-43T    15
# AXCP-78    11
# DDBN-89     8
# SDRT-67     6
# LXCV-21     5
# GCVB-79     5
# Name: count, dtype: int64

# %%
# Bar Chart : in  case of barachart X_axis variable is always a categorical data so bars not touch each other
df.MaterialID.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df.groupby('MaterialID').size().plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
# freq  A ,b ,c  = 50,40 ,10 

df.MaterialID.value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
sns.countplot(data=df,x='Location')
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
sns.barplot(data=df,x='Location',y='Quantity',estimator='sum')

# blck line is 95% confidence level interavl estimate
# Out:
# <Axes: xlabel='Location', ylabel='Quantity'>

# %%
plt.hist(df.Quantity)
# Out:
# (array([ 2., 17.,  6.,  8.,  8.,  3.,  2.,  2.,  0.,  2.]),
#  array([ 10. ,  24.2,  38.4,  52.6,  66.8,  81. ,  95.2, 109.4, 123.6,
#         137.8, 152. ]),
#  <BarContainer object of 10 artists>)

# %%
x1 = [9,40,70,100,120,160]
plt.hist(df.Quantity, bins=x1)
# Out:
# (array([21., 14.,  9.,  3.,  3.]),
#  array([  9.,  40.,  70., 100., 120., 160.]),
#  <BarContainer object of 5 artists>)

# %%
sns.histplot(data=df,x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.histplot(data=df,x='Quantity', bins=x1)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
x1 = [3.2, 8.9, 14.5, 20.3, 23.5, 9 , 28.5, 26.5, 25.3, 25.6, 17.9, 12.7]
plt.plot(x1)

# %%
# all the points are grater than upper fence or lower than lower fence are callad as outlier 


plt.boxplot(df.Quantity)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x210b8c1ae40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x210b8c1b0e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x210b8c1acf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x210b8c1b380>],
#  'fliers': [<matplotlib.lines.Line2D at 0x210b8c1b4d0>],
#  'means': []}

# %%
sns.boxplot(df.Quantity)
# Out:
# <Axes: ylabel='Quantity'>

# %%
newdf = df.pivot_table(index='MaterialID',columns='Location',values='Quantity',aggfunc='sum')

newdf
# Out:
# Location    MWH-1  MWH-2  MWH-3  MWH-4  MWH-5
# MaterialID
# AXCP-78     548.0   85.0   29.0   36.0  200.0
# DDBN-89     130.0   69.0   38.0   75.0   71.0
# GCVB-79       NaN  156.0    NaN    NaN   26.0
# LXCV-21       NaN   27.0   42.0    NaN  174.0
# SDRT-67      91.0   31.0    NaN   58.0  114.0
# TMI-43T     120.0   29.0   65.0  559.0  112.0

# %%
# effect of one categorical to another categorical data the wee make group bar chart and Stats-bar chart  

newdf.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df1 = df.iloc[np.where(df.Location=="MWH-1")[0]]

df2 = df.iloc[np.where(df.Location=="MWH-2")[0]]

df3 = df.iloc[np.where(df.Location=="MWH-3")[0]]

# %%
# wegiht of indivual consignment is higher in MWH1 

plt.boxplot([df1.Quantity , df2.Quantity , df3.Quantity])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x210bc7082f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x210bc708590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x210bc7081a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x210bc708830>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x210bc708980>,
# ...
#  'means': []}

# %%
ge =  pd.read_excel('CDAC_DataBook.xlsx', sheet_name='faithful')
ge.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
plt.scatter(ge.waiting , ge.eruptions)
