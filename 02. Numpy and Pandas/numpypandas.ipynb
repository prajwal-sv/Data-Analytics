# %%
import numpy as np 
import pandas as pd

# %%
a1 = np.array([5,9,8,3,9,1,2,7])
type(a1)
a1>=4
# Out:
# array([ True,  True,  True, False,  True, False, False,  True])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
t1 = np.where(a1>=4)  # remember this is use ver ofently in data analyis 
print(t1)
print(len(t1))
print(len(t1[0]))
print(a1[t1]) # this is only posible with array it not possibel in list  
print((a1>=4).sum()) # how many are thair meet the condtions
# Out:
# (array([0, 1, 2, 4, 7]),)
# 1
# 5
# [5 9 8 9 7]
# 5

# %%
# Q1 where are the value which meets the codntions 
#-> t1 = np.where(a1>=4)
#Q2 what are the value which meet a condions 
#->a1[t1]
#Q3 how many value meet the perticular condtions 
#->len(t1[0])

# %%
import os 
os.getcwd()  # give current working diretory\
# Out:
# 'c:\\Users\\praja\\Data-Analytics\\02. Numpy and Pandas'

# %%
os.chdir('C:\\Users\\praja\\Downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praja\\Downloads'

# %%
df = pd.read_excel('CDAC_DataBook.xlsx',sheet_name='ERPData') # it give data frame in ERPdata only

# %%
df
# Out:
#    MaterialID Location  Quantity
# 0     TMI-43T    MWH-4        34
# 1     AXCP-78    MWH-1        67
# 2     LXCV-21    MWH-2        27
# 3     AXCP-78    MWH-5        65
# 4     AXCP-78    MWH-4        36
# 5     TMI-43T    MWH-4        78
# 6     TMI-43T    MWH-4        31
# 7     TMI-43T    MWH-2        29
# 8     GCVB-79    MWH-2        10
# 9     TMI-43T    MWH-1       120
# 10    SDRT-67    MWH-1        34
# 11    SDRT-67    MWH-4        58
# 12    TMI-43T    MWH-4        76
# 13    TMI-43T    MWH-4        32
# 14    TMI-43T    MWH-3        65
# 15    GCVB-79    MWH-2        87
# 16    SDRT-67    MWH-5        12
# 17    SDRT-67    MWH-5       102
# 18    TMI-43T    MWH-4        34
# 19    TMI-43T    MWH-4        52
# 20    TMI-43T    MWH-4        39
# 21    TMI-43T    MWH-4        75
# 22    DDBN-89    MWH-4        48
# 23    DDBN-89    MWH-5        71
# 24    AXCP-78    MWH-1       152
# 25    AXCP-78    MWH-1       109
# 26    DDBN-89    MWH-1        57
# ...

# %%
x1 = df.Quantity#
print(x1)
# Out:
# 0      34
# 1      67
# 2      27
# 3      65
# 4      36
# 5      78
# 6      31
# 7      29
# 8      10
# 9     120
# 10     34
# 11     58
# 12     76
# 13     32
# 14     65
# 15     87
# 16     12
# 17    102
# 18     34
# 19     52
# 20     39
# 21     75
# 22     48
# 23     71
# 24    152
# 25    109
# 26     57
# 27     83
# 28     34
# 29     57
# 30     27
# 31     65
# 32     43
# 33    112
# 34     26
# 35     31
# 36     28
# 37     65
# 38     70
# 39    145
# 40     34
# 41     57
# 42     31
# 43     38
# 44     42
# 45     69
# 46     85
# 47     29
# 48     75
# 49     39
# Name: Quantity, dtype: int64

# %%
type(x1)
# Out:
# pandas.Series

# %%
sum(x1)
# Out:
# 2885

# %%
(df.Quantity>=80).sum()
# Out:
# np.int64(9)

# %%
len(np.where(df.Quantity>=80)[0])
# Out:
# 9

# %%
np.where(df.Quantity == max(df.Quantity))
# Out:
# (array([24]),)

# %%
df.Location[np.where(df.Quantity == max(df.Quantity))[0]]
# Out:
# 24    MWH-1
# Name: Location, dtype: str

# %%
np.where(df.Quantity == max(df.Quantity))[0]
# Out:
# array([24])

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
np.unique(df.MaterialID)
# Out:
# array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#       dtype=object)

# %%
np.unique(df.Location)
# Out:
# array(['MWH-1', 'MWH-2', 'MWH-3', 'MWH-4', 'MWH-5'], dtype=object)

# %%
#GoupBy Cammand is only usededd in categoricacl data 
#grouping can be done in multiple colums 
grp1 = df.groupby('Location')
grp2 = df.groupby('MaterialID')
grp3 = df.groupby(['MaterialID' ,'Location'])
grp4 = df.groupby(['Location','MaterialID'])
grp1.Quantity.agg(['sum' ,'mean' ,'size'])
# Out:
#           sum       mean  size
# Location
# MWH-1     889  80.818182    11
# MWH-2     397  44.111111     9
# MWH-3     174  43.500000     4
# MWH-4     728  48.533333    15
# MWH-5     697  63.363636    11

# %%
grp2.Quantity.agg(['sum','mean','size'])
# Out:
#             sum       mean  size
# MaterialID
# AXCP-78     898  81.636364    11
# DDBN-89     383  47.875000     8
# GCVB-79     182  36.400000     5
# LXCV-21     243  48.600000     5
# SDRT-67     294  49.000000     6
# TMI-43T     885  59.000000    15

# %%
grp3.Quantity.agg(['sum','mean','size'])
grp3["Quantity"]

# %%
df1= grp4.Quantity.agg(['sum','mean','size'])
# Out:
#                      sum        mean  size
# Location MaterialID
# MWH-1    AXCP-78     548  109.600000     5
#          DDBN-89     130   43.333333     3
#          SDRT-67      91   45.500000     2
#          TMI-43T     120  120.000000     1
# MWH-2    AXCP-78      85   85.000000     1
#          DDBN-89      69   69.000000     1
#          GCVB-79     156   39.000000     4
#          LXCV-21      27   27.000000     1
#          SDRT-67      31   31.000000     1
#          TMI-43T      29   29.000000     1
# MWH-3    AXCP-78      29   29.000000     1
#          DDBN-89      38   38.000000     1
#          LXCV-21      42   42.000000     1
#          TMI-43T      65   65.000000     1
# MWH-4    AXCP-78      36   36.000000     1
#          DDBN-89      75   37.500000     2
#          SDRT-67      58   58.000000     1
#          TMI-43T     559   50.818182    11
# MWH-5    AXCP-78     200   66.666667     3
#          DDBN-89      71   71.000000     1
# ...

# %%
df2 = df1.loc['MWH-1']
df2
# Out:
#             sum        mean  size
# MaterialID
# AXCP-78     548  109.600000     5
# DDBN-89     130   43.333333     3
# SDRT-67      91   45.500000     2
# TMI-43T     120  120.000000     1

# %%
df2.to_excel('C:\\Users\\praja\\Data-Analytics\\02. Numpy and Pandas\\myData.xlsx') #you cam save the perticualr colums

# %%
pd.read_excel('C:\\Users\\praja\\Data-Analytics\\02. Numpy and Pandas\\myData.xlsx')
# Out:
#   MaterialID  sum        mean  size
# 0    AXCP-78  548  109.600000     5
# 1    DDBN-89  130   43.333333     3
# 2    SDRT-67   91   45.500000     2
# 3    TMI-43T  120  120.000000     1

# %%
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
ind =  np.where(df.Quantity < 70)[0]

# %%
df1 = df.iloc[ind]
df2 = df.drop(ind)

# %%
max(df1.Quantity)
# Out:
# 69

# %%
min(df1.Quantity)
# Out:
# 10

# %%
ind  = np.where((df.Location == 'MWH-1')&(df.Quantity>80))

ind
# Out:
# (array([ 9, 24, 25, 39]),)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MaterialID  50 non-null     str
#  1   Location    50 non-null     str
#  2   Quantity    50 non-null     int64
# dtypes: int64(1), str(2)
# memory usage: 1.9 KB

# %%
pune = pd.read_excel('CDAC_DataBook.xlsx',sheet_name="Pune")

# %%
mumbai = pd.read_excel('CDAC_DataBook.xlsx' , sheet_name='Mumbai')

# %%
pune
# Out:
#       Name      Subject Grade
# 0   Rakesh       Python     A
# 1    Manoj     MLPython     C
# 2  Vaibhav   Statistics     B
# 3   Hitesh   CommSkills     A
# 4   Suyash  ProjectMgmt     B

# %%
mumbai
# Out:
#        Name     Subject Grade
# 0   Vaibhav   Six Sigma     A
# 1   Deepika  Statistics     B
# 2     Arjun  CommSkills     A
# 3    Chetan      Python     A
# 4  Abhishek    MLPython     B

# %%
pd.merge(pune,mumbai,on='Subject')
# Out:
#     Name_x     Subject Grade_x    Name_y Grade_y
# 0   Rakesh      Python       A    Chetan       A
# 1    Manoj    MLPython       C  Abhishek       B
# 2  Vaibhav  Statistics       B   Deepika       B
# 3   Hitesh  CommSkills       A     Arjun       A

# %%
pd.merge(pune,mumbai,on='Grade')
# Out:
#     Name_x    Subject_x Grade    Name_y   Subject_y
# 0   Rakesh       Python     A   Vaibhav   Six Sigma
# 1   Rakesh       Python     A     Arjun  CommSkills
# 2   Rakesh       Python     A    Chetan      Python
# 3  Vaibhav   Statistics     B   Deepika  Statistics
# 4  Vaibhav   Statistics     B  Abhishek    MLPython
# 5   Hitesh   CommSkills     A   Vaibhav   Six Sigma
# 6   Hitesh   CommSkills     A     Arjun  CommSkills
# 7   Hitesh   CommSkills     A    Chetan      Python
# 8   Suyash  ProjectMgmt     B   Deepika  Statistics
# 9   Suyash  ProjectMgmt     B  Abhishek    MLPython

# %%
pd.merge(pune,mumbai,on=['Grade','Subject'])
# Out:
#     Name_x     Subject Grade   Name_y
# 0   Rakesh      Python     A   Chetan
# 1  Vaibhav  Statistics     B  Deepika
# 2   Hitesh  CommSkills     A    Arjun

# %%
pd.merge(pune,mumbai,on=['Grade','Subject','Name'])
# Out:
# Empty DataFrame
# Columns: [Name, Subject, Grade]
# Index: []
